# %%
import pandas as pd
import numpy as np

# %%
my_data = np.random.randint(0,101,(4,3))
my_data
# Out:
# array([[ 5, 86, 21],
#        [93, 42, 96],
#        [ 2, 37, 14],
#        [67, 91, 66]])

# %%
my_index =['India','Australia','NewZealand','England']
my_cols = ['Jan','Feb','Mar']
df =  pd.DataFrame(my_data,index=my_index,columns=my_cols)
df
# Out:
#             Jan  Feb  Mar
# India         5   86   21
# Australia    93   42   96
# NewZealand    2   37   14
# England      67   91   66

# %%
df1=pd.read_csv("E:\\Python\\PythonProgrammes\\emp_details.csv")
df1.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
df1.describe()
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
df1.shape
# Out:
# (50, 11)

# %%
df1.columns
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df4= df1.rename(columns={"EMPLOYEE_ID":"EMP_NO","MANAGER_ID":"MGR_NO","COMMISSION_PCT":"COMM"})
df4.head(3)
# Out:
#    EMP_NO FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# 0     198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 1     199    Douglas     Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 2     200   Jennifer    Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
#
#    SALARY COMM MGR_NO  DEPARTMENT_ID
# 0    2600   -     124             50
# 1    2600   -     124             50
# 2    4400   -     101             10

# %%
df4.describe().transpose()
# Out:
#                count     mean          std     min      25%     50%      75%  \
# EMP_NO          50.0   134.76    33.631594   100.0   112.25   124.5   136.75
# SALARY          50.0  6182.32  4586.181772  2100.0  2725.00  4600.0  8150.00
# DEPARTMENT_ID   50.0    57.60    25.116870    10.0    50.00    50.0    60.00
#
#                    max
# EMP_NO           206.0
# SALARY         24000.0
# DEPARTMENT_ID    110.0

# %%
df5=df4.set_index('EMP_NO').head()
df5
# Out:
#        FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# EMP_NO
# 198        Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 199       Douglas      Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 200      Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
# 201       Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
# 202           Pat        Fay      PFAY  603.123.6666  17-AUG-05    MK_REP
#
#         SALARY COMM MGR_NO  DEPARTMENT_ID
# EMP_NO
# 198       2600   -     124             50
# 199       2600   -     124             50
# 200       4400   -     101             10
# 201      13000   -     100             20
# 202       6000   -     201             20

# %%
df6 = df5.reset_index()
df6
# Out:
#    EMP_NO FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# 0     198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 1     199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 2     200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
# 3     201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
# 4     202        Pat        Fay      PFAY  603.123.6666  17-AUG-05    MK_REP
#
#    SALARY COMM MGR_NO  DEPARTMENT_ID
# 0    2600   -     124             50
# 1    2600   -     124             50
# 2    4400   -     101             10
# 3   13000   -     100             20
# 4    6000   -     201             20

# %%
for i in df6.iloc[0]:
    print(i)
# Out:
# 198
# Donald
# OConnell
# DOCONNEL
# 650.507.9833
# 21-JUN-07
# SH_CLERK
# 2600
#  -
# 124
# 50

# %%
df6.iloc[0:4]
# Out:
#    EMP_NO FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# 0     198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 1     199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 2     200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
# 3     201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
#
#    SALARY COMM MGR_NO  DEPARTMENT_ID
# 0    2600   -     124             50
# 1    2600   -     124             50
# 2    4400   -     101             10
# 3   13000   -     100             20

# %%
df7 = df6.set_index('EMP_NO')

# %%
df7.loc[[198,201]]
# Out:
#        FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# EMP_NO
# 198        Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 201       Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
#
#         SALARY COMM MGR_NO  DEPARTMENT_ID
# EMP_NO
# 198       2600   -     124             50
# 201      13000   -     100             20

# %%
df6.head()
# Out:
#    EMP_NO FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# 0     198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 1     199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 2     200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
# 3     201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
# 4     202        Pat        Fay      PFAY  603.123.6666  17-AUG-05    MK_REP
#
#    SALARY COMM MGR_NO  DEPARTMENT_ID
# 0    2600   -     124             50
# 1    2600   -     124             50
# 2    4400   -     101             10
# 3   13000   -     100             20
# 4    6000   -     201             20

# %%
df7.drop(198,axis=0)
# Out:
#        FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# EMP_NO
# 199       Douglas      Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 200      Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03   AD_ASST
# 201       Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04    MK_MAN
# 202           Pat        Fay      PFAY  603.123.6666  17-AUG-05    MK_REP
#
#         SALARY COMM MGR_NO  DEPARTMENT_ID
# EMP_NO
# 199       2600   -     124             50
# 200       4400   -     101             10
# 201      13000   -     100             20
# 202       6000   -     201             20

# %%
df1.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
df1[df1['SALARY']>=10000]
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 6           204    Hermann       Baer     HBAER  515.123.8888  07-JUN-02
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 23          114        Den   Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 3    MK_MAN   13000             -         100             20
# 6    PR_REP   10000             -         101             70
# 7    AC_MGR   12008             -         101            110
# 9   AD_PRES   24000             -          -              90
# ...

# %%
df1[df1['JOB_ID']=='AD_VP']
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 10          101      Neena   Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex   De Haan   LDEHAAN  515.123.4569  13-JAN-01
#
#    JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 10  AD_VP   17000             -         100             90
# 11  AD_VP   17000             -         100             90

# %%
df1[(df1['DEPARTMENT_ID']==90) & (df1['SALARY']>=10000)]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 9           100     Steven      King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena   Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex   De Haan   LDEHAAN  515.123.4569  13-JAN-01
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 9   AD_PRES   24000             -          -              90
# 10    AD_VP   17000             -         100             90
# 11    AD_VP   17000             -         100             90

# %%
opts = ['AD_PRES','AD_VP']
df1[df1['JOB_ID'].isin(opts)]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 9           100     Steven      King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena   Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex   De Haan   LDEHAAN  515.123.4569  13-JAN-01
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 9   AD_PRES   24000             -          -              90
# 10    AD_VP   17000             -         100             90
# 11    AD_VP   17000             -         100             90

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df1["lastfour"]=df1["PHONE_NUMBER"].apply(last_four)
df1.head(3)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas     Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer    Whalen   JWHALEN  515.123.4444  17-SEP-03
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour
# 0  SH_CLERK    2600             -         124             50     9833
# 1  SH_CLERK    2600             -         124             50     9844
# 2   AD_ASST    4400             -         101             10     4444

# %%
df1.JOB_ID.unique()
# Out:
# array(['SH_CLERK', 'AD_ASST', 'MK_MAN', 'MK_REP', 'HR_REP', 'PR_REP',
#        'AC_MGR', 'AC_ACCOUNT', 'AD_PRES', 'AD_VP', 'IT_PROG', 'FI_MGR',
#        'FI_ACCOUNT', 'PU_MAN', 'PU_CLERK', 'ST_MAN', 'ST_CLERK'],
#       dtype=object)

# %%
def cal_comm(jobid,sal):
    if jobid == 'ST_MAN':
        return sal*0.05

# %%
df1["COMMISSION"] =np.vectorize(cal_comm)(df1["JOB_ID"],df1["SALARY"])
df1[df1["JOB_ID"] == 'ST_MAN']
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 29          120    Matthew     Weiss    MWEISS  650.123.1234  18-JUL-04
# 30          121       Adam     Fripp    AFRIPP  650.123.2234  10-APR-05
# 31          122      Payam  Kaufling  PKAUFLIN  650.123.3234  01-MAY-03
# 32          123     Shanta   Vollman  SVOLLMAN  650.123.4234  10-OCT-05
# 33          124      Kevin   Mourgos  KMOURGOS  650.123.5234  16-NOV-07
#
#     JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 29  ST_MAN    8000             -         100             50     1234
# 30  ST_MAN    8200             -         100             50     2234
# 31  ST_MAN    7900             -         100             50     3234
# 32  ST_MAN    6500             -         100             50     4234
# 33  ST_MAN    5800             -         100             50     5234
#
#    COMMISSION
# 29      400.0
# 30      410.0
# 31      395.0
# 32      325.0
# 33      290.0

# %%
df1.sort_values('SALARY',ascending=False).head()
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-AUG-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 9   AD_PRES   24000             -          -              90     4567
# 11    AD_VP   17000             -         100             90     4569
# 10    AD_VP   17000             -         100             90     4568
# 3    MK_MAN   13000             -         100             20     5555
# 17   FI_MGR   12008             -         101            100     4569
#
#    COMMISSION
# 9        None
# 11       None
# 10       None
# 3        None
# 17       None

# %%
df1.sort_values(["SALARY","COMMISSION"],ascending=False).head()
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-JUN-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 9   AD_PRES   24000             -          -              90     4567
# 10    AD_VP   17000             -         100             90     4568
# 11    AD_VP   17000             -         100             90     4569
# 3    MK_MAN   13000             -         100             20     5555
# 7    AC_MGR   12008             -         101            110     8080
#
#    COMMISSION
# 9        None
# 10       None
# 11       None
# 3        None
# 7        None

# %%
df1["SALARY"].max()
# Out:
# 24000

# %%
df1["SALARY"].idxmax()
# Out:
# 9

# %%
df1["SALARY"].min()
# Out:
# 2100

# %%
df1["SALARY"].idxmin()
# Out:
# 41

# %%
df1["JOB_ID"].value_counts()
# Out:
# ST_CLERK      16
# ST_MAN         5
# PU_CLERK       5
# FI_ACCOUNT     5
# IT_PROG        5
# AD_VP          2
# SH_CLERK       2
# AC_ACCOUNT     1
# AD_ASST        1
# AC_MGR         1
# PR_REP         1
# FI_MGR         1
# HR_REP         1
# PU_MAN         1
# MK_REP         1
# MK_MAN         1
# AD_PRES        1
# Name: JOB_ID, dtype: int64

# %%
df1["JOB_ID"].replace('AC_MGR','BEAN COUNTER').value_counts()
# Out:
# ST_CLERK        16
# ST_MAN           5
# PU_CLERK         5
# FI_ACCOUNT       5
# IT_PROG          5
# AD_VP            2
# SH_CLERK         2
# AC_ACCOUNT       1
# AD_ASST          1
# BEAN COUNTER     1
# PR_REP           1
# FI_MGR           1
# HR_REP           1
# PU_MAN           1
# MK_REP           1
# MK_MAN           1
# AD_PRES          1
# Name: JOB_ID, dtype: int64

# %%
df1[df1['SALARY'].between(5000,10000,'both')]
# Out:
#     EMPLOYEE_ID   FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 4           202          Pat       Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan    Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann      Baer     HBAER  515.123.8888  07-JUN-02
# 8           206      William     Gietz    WGIETZ  515.123.8181  07-JUN-02
# 12          103    Alexander    Hunold   AHUNOLD  590.423.4567  03-JAN-06
# 13          104        Bruce     Ernst    BERNST  590.423.4568  21-MAY-07
# 18          109       Daniel    Faviet   DFAVIET  515.124.4169  16-AUG-02
# 19          110         John      Chen     JCHEN  515.124.4269  28-SEP-05
# 20          111       Ismael   Sciarra  ISCIARRA  515.124.4369  30-SEP-05
# 21          112  Jose Manuel     Urman   JMURMAN  515.124.4469  07-MAR-06
# 22          113         Luis      Popp     LPOPP  515.124.4567  07-DEC-07
# 29          120      Matthew     Weiss    MWEISS  650.123.1234  18-JUL-04
# ...

# %%
df1.nlargest(5,"SALARY")
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-JUN-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 9   AD_PRES   24000             -          -              90     4567
# 10    AD_VP   17000             -         100             90     4568
# 11    AD_VP   17000             -         100             90     4569
# 3    MK_MAN   13000             -         100             20     5555
# 7    AC_MGR   12008             -         101            110     8080
#
#    COMMISSION
# 9        None
# 10       None
# 11       None
# 3        None
# 7        None

# %%
df1.nsmallest(5,"SALARY")
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 41          132         TJ       Olson   TJOLSON  650.124.8234  10-APR-07
# 37          128     Steven      Markle   SMARKLE  650.124.1434  08-MAR-08
# 45          136      Hazel  Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 36          127      James      Landry   JLANDRY  650.124.1334  14-JAN-07
# 44          135         Ki         Gee      KGEE  650.127.1734  12-DEC-07
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 41  ST_CLERK    2100             -         121             50     8234
# 37  ST_CLERK    2200             -         120             50     1434
# 45  ST_CLERK    2200             -         122             50     1634
# 36  ST_CLERK    2400             -         120             50     1334
# 44  ST_CLERK    2400             -         122             50     1734
#
#    COMMISSION
# 41       None
# 37       None
# 45       None
# 36       None
# 44       None

# %%
df1.isnull().head()
# Out:
#    EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  JOB_ID  \
# 0        False       False      False  False         False      False   False
# 1        False       False      False  False         False      False   False
# 2        False       False      False  False         False      False   False
# 3        False       False      False  False         False      False   False
# 4        False       False      False  False         False      False   False
#
#    SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  lastfour  COMMISSION
# 0   False           False       False          False     False        True
# 1   False           False       False          False     False        True
# 2   False           False       False          False     False        True
# 3   False           False       False          False     False        True
# 4   False           False       False          False     False        True

# %%
df1.notnull().head()
# Out:
#    EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  JOB_ID  \
# 0         True        True       True   True          True       True    True
# 1         True        True       True   True          True       True    True
# 2         True        True       True   True          True       True    True
# 3         True        True       True   True          True       True    True
# 4         True        True       True   True          True       True    True
#
#    SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  lastfour  COMMISSION
# 0    True            True        True           True      True       False
# 1    True            True        True           True      True       False
# 2    True            True        True           True      True       False
# 3    True            True        True           True      True       False
# 4    True            True        True           True      True       False

# %%
df1[df1["COMMISSION"].notnull()]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 29          120    Matthew     Weiss    MWEISS  650.123.1234  18-JUL-04
# 30          121       Adam     Fripp    AFRIPP  650.123.2234  10-APR-05
# 31          122      Payam  Kaufling  PKAUFLIN  650.123.3234  01-MAY-03
# 32          123     Shanta   Vollman  SVOLLMAN  650.123.4234  10-OCT-05
# 33          124      Kevin   Mourgos  KMOURGOS  650.123.5234  16-NOV-07
#
#     JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 29  ST_MAN    8000             -         100             50     1234
# 30  ST_MAN    8200             -         100             50     2234
# 31  ST_MAN    7900             -         100             50     3234
# 32  ST_MAN    6500             -         100             50     4234
# 33  ST_MAN    5800             -         100             50     5234
#
#    COMMISSION
# 29      400.0
# 30      410.0
# 31      395.0
# 32      325.0
# 33      290.0

# %%
df1.fillna(100).head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID lastfour  \
# 0  SH_CLERK    2600             -         124             50     9833
# 1  SH_CLERK    2600             -         124             50     9844
# 2   AD_ASST    4400             -         101             10     4444
# 3    MK_MAN   13000             -         100             20     5555
# 4    MK_REP    6000             -         201             20     6666
#
#    COMMISSION
# 0       100.0
# 1       100.0
# 2       100.0
# 3       100.0
# 4       100.0

# %%
df1["DEPARTMENT_ID"].value_counts()
# Out:
# 50     23
# 100     6
# 30      6
# 60      5
# 90      3
# 20      2
# 110     2
# 10      1
# 40      1
# 70      1
# Name: DEPARTMENT_ID, dtype: int64

# %%
df1.groupby(df1["JOB_ID"])
# Out:
#             EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  \
# JOB_ID
# AC_ACCOUNT            1           1          1      1             1
# AC_MGR                1           1          1      1             1
# AD_ASST               1           1          1      1             1
# AD_PRES               1           1          1      1             1
# AD_VP                 2           2          2      2             2
# FI_ACCOUNT            5           5          5      5             5
# FI_MGR                1           1          1      1             1
# HR_REP                1           1          1      1             1
# IT_PROG               5           5          5      5             5
# MK_MAN                1           1          1      1             1
# MK_REP                1           1          1      1             1
# PR_REP                1           1          1      1             1
# PU_CLERK              5           5          5      5             5
# ...
